# %% [markdown]
# # Geometry Notes
# ---

# %% [markdown]
# ![My image](Image_001.png)

# %% [markdown]
# # TODO
# ---
# - Look up what a quaternion is, familiarize yourself with this concept (watch YouTube videos)
