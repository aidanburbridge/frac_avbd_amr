# %% [markdown]
# # Solid Mechanics Augmented Vertex Block Descent
# ___

# %% [markdown]
# ### Poisson's Ratio
# #### Core Problem:
# The 2D voxels will need to pull in laterally for an axial tensile stress and vice versa for compression.
# The core voxels are rigid, so overlap would be punished.
# Ideas to get around this.
# * One idea would be to dynamically adjust the shape of the voxels, so in other words there could be a parameter that relates the width and height of cells with a ratio that scales with stress, could run into issues with the constraints - (getting punished by overlap) ? - would this cause weird graphical issues as well as the material
# * Could keep shape consistent and make a constraint that forces overlap actually.
